# %%
import xml.etree.ElementTree as ET

xml_filename = "test.xml"
xml_fileIO = open(xml_filename, "r", encoding="utf16")
xml_file_contents = xml_fileIO.read()
print(xml_file_contents)

xml_file_parsed = ET.fromstring(xml_file_contents)
xml_fileIO.close()


print(xml_file_parsed)
# Out:
# <log_file>
# <events>
# <event>
# <id_event>1</id_event><time>23 : 08 : 35</time><time2>00 : 01 : 52</time2><user>Xristos</user><action>Insert Entity</action><attribute>[Decision, (x=696,y=430,w=90,h=60), Decision (1), 1]</attribute><typology /><comments /><added_by_user>false</added_by_user>
# </event>
# <event>
# <id_event>2</id_event><time>23 : 08 : 37</time><time2>00 : 01 : 54</time2><user>Xristos</user><action>Insert Entity</action><attribute>[Process, (x=694,y=256,w=90,h=60), Process (2), 2]</attribute><typology /><comments /><added_by_user>false</added_by_user>
# </event>
# <event>
# <id_event>3</id_event><time>23 : 08 : 40</time><time2>00 : 01 : 58</time2><user>Xristos</user><action>Set object to front</action><attribute>[Process (2)]</attribute><typology /><comments /><added_by_user>false</added_by_user>
# </event>
# <event>
# ...
